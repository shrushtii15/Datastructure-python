# %% [markdown]
# Data structure

# %% [markdown]
# 1. What are data structure and why are they important
#     - Data structures organize and store data efficiently, enabling fast access, modification, and management. They make programs run faster and solve problems more efficiently.
#
# 2. Explain the difference between mutable and immutable data types with examples
#     - Mutable data types are the data types that are further change after the creation, but immutable datatypes ate the types of data types ehich cannot be changed after the creation of the dataypes.
#
# 3.  What are the main differences between lists and tuples in Python
#     - list are the types of data structure that stored hetrogenous values which is mutable and are enclosed and sqaure brackets.
#     - tuples are the type of data structure that also storeshetrogenous data types but are immutable and are inclosed in parathesis.
#
# 4.  Describe how dictionaries store data
#     - Dictionary stores the data in the key value pair and also stores hetrogenous data and are enclosed in curly braces.
#
# 5.  Why might you use a set instead of a list in Python3
#     -  Sets automatically remove duplicate values, while lists allow duplicates.Sets don’t maintain order, Sets also support mathematical operations like union, intersection, and difference, which are not as efficient with lists.
#
# 6.  What is a string in Python, and how is it different from a list
#     - A string in Python is a sequence of characters enclosed in quotes (' ', " ", ''' ''', or """ """). It is used to store and manipulate text.
#      string is immutable but list are mutable.
#
# 7. How do tuples ensure data integrity in Python
#     - A tuple in Python is an immutable sequence, meaning its elements cannot be changed, added, or removed after creation. This immutability helps ensure data integrity
#
# 8. What is a hash table, and how does it relate to dictionaries in Python
#     - A hash table is a data structure that stores key-value pairs using a hash function to compute an index, allowing fast data retrieval. It provides average O(1) time complexity for lookups, insertions, and deletions.
#
# 9. Can lists contain different data types in Python
#     - Yes
#
# 10. Explain why strings are immutable in Python
#     - In Python, strings are immutable, meaning their contents cannot be changed after creation. Python makes strings immutable to enhance performance, security, and memory efficiency, ensuring they remain stable and reliable.
#
# 11. What advantages do dictionaries offer over lists for certain tasks
#
#     - Dictionaries store data as key-value pairs, making them ideal for structured data, unlike lists that store elements sequentially.Keys in a dictionary are unique, preventing duplicate entries, unlike lists where duplicates are common.
#
# 12. Describe a scenario where using a tuple would be preferable over a list
#     - Scenario: Storing GPS Coordinates (Latitude, Longitude)
#      Imagine you're developing a mapping application that stores GPS coordinates for specific locations. Since GPS coordinates never change, using a tuple instead of a list is preferable.
#
# 13. How do sets handle duplicate values in Python
#     - In Python, sets automatically remove duplicate values when elements are added. This ensures that each element in a set is unique.
#
# 14. How does the “in” keyword work differently for lists and dictionaries
#      -  Use in with lists when searching for a specific value.
#         Use in with dictionaries when checking if a key exists.
#
# 15. Can you modify the elements of a tuple? Explain why or why not
#      - Tuples are immutable, meaning their elements cannot be changed, added, or removed after creation. This immutability exist becuse of Memory Efficiency, dataintegrity.
#
# 16. What is a nested dictionary, and give an example of its use case
#     - A nested dictionary is a dictionary inside another dictionary. It allows you to store structured data hierarchically.
#
# 17. Describe the time complexity of accessing elements in a dictionaryP
#     - Accessing elements in a dictionary (hash table) has an average-case time complexity of O(1) and a worst-case time complexity of O(n).
#
# 18. In what situations are lists preferred over dictionaries
#     - Lists are preferred over dictionaries for ordered data, efficient iteration, indexed access, lower memory usage, and when no key-value relationship is needed. They excel in sequential processing, stack/queue operations, and scenarios requiring minimal overhead without complex lookups.
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval
#     - Dictionaries are considered unordered because they store key-value pairs using a hash table, where elements are placed based on their hash values, not a fixed sequence.
#
# 20.  Explain the difference between a list and a dictionary in terms of data retrieval.
#     - Lists use index-based retrieval, offering direct access to elements by position (O(1) time complexity). Dictionaries use key-based retrieval, also efficient on average (O(1)), but store data in key-value pairs and maintain insertion order.

# %% [markdown]
# # **Data Structure**

# %%
# 1. Write a code to create a string with your name and print it

name = "Shrushti Dongre"
print(name)
print(type(name))
# Out:
# Shrushti Dongre
# <class 'str'>

# %%
# 2. Write a code to find the length of the string "Hello World"
string_1 = "Hello World"
print(len(string_1))
# Out:
# 11

# %%
# 3. Write a code to slice the first 3 characters from the string "Python Programming"
string_2 = "Python Programming"
print(string_2[0:3])
# Out:
# Pyt

# %%
# 4. Write a code to convert the string "hello" to uppercase
string_3 = "hello"
print(string_3.upper())
# Out:
# HELLO

# %%
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple"
string_4 = "I like apple"
string_4.replace("apple" ,"orange")
# Out:
# 'I like orange'

# %%
#6. Write a code to create a list with numbers 1 to 5 and print it
list_1 = [1,2,3,4,5]
print(list_1)
# Out:
# [1, 2, 3, 4, 5]

# %%
#7. Write a code to append the number 10 to the list [1, 2, 3, 4]
list_2 = [1,2,3,4]
list_2.append(10)
print(list_2)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
list_3 = [1,2,3,4,5]
list_3.pop(2)
print(list_3)
# Out:
# [1, 2, 4, 5]

# %%
#9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']
list_4 = ['a', 'b', 'c', 'd']
print(list_4[1])
# Out:
# b

# %%
#10.  Write a code to reverse the list [10, 20, 30, 40, 50]
list_5 = [10, 20, 30, 40, 50]
list_5.reverse()
print(list_5)
# Out:
# [50, 40, 30, 20, 10]

# %%
#11.  Write a code to create a tuple with the elements 100, 200, 300 and print it.
tup_1 = (100, 200, 300)
print(tup_1)
print(type(tup_1))
# Out:
# (100, 200, 300)
# <class 'tuple'>

# %%
# 12.  Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
tup_2 = ('red', 'green', 'blue', 'yellow')
print(tup_2[-2])
# Out:
# blue

# %%
# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).
tup_3 = (10, 20, 5, 15)
print(min(tup_3))
# Out:
# 5

# %%
# 14  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
tup_4 = ('dog', 'cat', 'rabbit')
print(tup_4.index("cat"))
# Out:
# 1

# %%
#15 Write a code to create a tuple containing three different fruits and check if "kiwi" is in it
fruits = ("apple","mango","kiwi")
print("kiwi" in fruits)
# Out:
# True

# %%
#16  Write a code to create a set with the elements 'a', 'b', 'c' and print it.
set_1 = {'a', 'b', 'c'}
print(set_1)
print(type(set_1))
# Out:
# {'b', 'c', 'a'}
# <class 'set'>

# %%
#17 Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
set_2 = {1, 2, 3, 4, 5}
print(set_2.clear())
print(type(set_2))
print(set_2)
# Out:
# None
# <class 'set'>
# set()

# %%
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

set_3 = {1, 2, 3, 4}
set_3.pop()
print(set_3)
# Out:
# {2, 3, 4}

# %%
#  19 Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
set_4 = {1, 2, 3}
set_5 = {3, 4, 5}
print(set_4|set_5)
# Out:
# {1, 2, 3, 4, 5}

# %%
#  20  write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}
set_6 = {1, 2, 3}
set_7 = {2, 3, 4}
print(set_6&set_7)
# Out:
# {2, 3}

# %%
#21  Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
dict_1 = {"name":"shrushti","age":20,"City":"Indore"}
print(dict_1)
print(type(dict_1))
# Out:
# {'name': 'shrushti', 'age': 20, 'City': 'Indore'}
# <class 'dict'>

# %%
# 22 Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}
dict_2 = {'name': 'John', 'age': 25}
dict_2["country"] = "USA"
print(dict_2)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# 23. Write a code to access the value associated with the key "name" in the dictionary .
dict_3 = {'name': 'Alice', 'age': 30}
print(dict_3["name"])
# Out:
# Alice

# %%
#24 Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
dict_4 = {'name': 'Bob', 'age': 22, 'city': 'New York'}
dict_4.pop("age")
print(dict_4)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#25 Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
dict_5 = {'name': 'Alice', 'city': 'Paris'}
print("city" in dict_5)
# Out:
# True

# %%
# 26 Write a code to create a list, a tuple, and a dictionary, and print them all.
my_list = [10, 20, 30, 40]

my_tuple = (1, 2, 3, 4)

my_dict = {'name': 'Alice', 'age': 28, 'city': 'New York'}

print("List:", my_list)
print("Tuple:", my_tuple)
print("Dictionary:", my_dict)
# Out:
# List: [10, 20, 30, 40]
# Tuple: (1, 2, 3, 4)
# Dictionary: {'name': 'Alice', 'age': 28, 'city': 'New York'}

# %%
# 27 Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
# result.(replaced)
import random

random_numbers = []
for i in range(5):
    num = random.randint(1, 100)
    random_numbers.append(num)

random_numbers.sort()

print("Sorted Random Numbers:", random_numbers)
# Out:
# Sorted Random Numbers: [16, 41, 75, 76, 80]

# %%
#28  Write a code to create a list with strings and print the element at the third index.
list_new = ["apple","boy","cat","dog","Elephant"]
list_new.insert(3,"shrushti")
print(list_new)
# Out:
# ['apple', 'boy', 'cat', 'shrushti', 'dog', 'Elephant']

# %%
# 29. Write a code to combine two dictionaries into one and print the result

dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
dict1.update(dict2)
print("Combined Dictionary:", dict1)
# Out:
# Combined Dictionary: {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Write a code to convert a list of strings into a set.

string_list = ["apple", "banana", "cherry", "apple", "banana"]
string_set = set(string_list)

print("Set of Strings:", string_set)
# Out:
# Set of Strings: {'apple', 'cherry', 'banana'}
